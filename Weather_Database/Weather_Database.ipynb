# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm output count.
len(cities)
# Out:
# 719

# %%
# Base URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7130ff2caeb6d2724a6cefcb729b6590

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
#       print(city_weather)
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        #print("lat", city_weather["coord"]["lat"])
        city_lng = city_weather["coord"]["lon"]
        #print("longitude", city_weather["coord"]["lon"])
        city_max_temp = city_weather["main"]["temp_max"]
        #print("max temp", city_weather["main"]["temp_max"])
        city_humidity = city_weather["main"]["humidity"]
        #print("humidity", city_weather["main"]["humidity"])
        city_clouds = city_weather["clouds"]["all"]
        #print("clouds", city_weather["clouds"]["all"])
        city_wind = city_weather["wind"]["speed"]
        #print("wind", city_weather["wind"]["speed"])
        city_weather_description = city_weather["weather"][0]["description"]
        #print("description", city_weather["weather"][0]["description"])
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #print(city_date)
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country, 
                          "Lat": city_lat,
                           "Lng": city_lng,
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Weather Description": city_weather_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | abha
# Processing Record 3 of Set 1 | maraa
# Processing Record 4 of Set 1 | srednekolymsk
# Processing Record 5 of Set 1 | yumen
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | kidal
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | luang prabang
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | changli
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | lorengau
# Processing Record 16 of Set 1 | inhambane
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | saldanha
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 1 | tazovskiy
# Processing Record 23 of Set 1 | salym
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | puerto del rosario
# Processing Record 26 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 1 | port angeles
# Processing Record 28 of Set 1 | sancti spiritus
# Processing Record 29 of Set 1 | samarai
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | mehamn
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | mount isa
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | hambantota
# Processing Record 42 of Set 1 | lagoa
# Processing Record 43 of Set 1 | dwarka
# Processing Record 44 of Set 1 | maningrida
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | condoto
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | payo
# Processing Record 49 of Set 1 | college
# Processing Record 50 of Set 1 | te anau
# Processing Record 1 of Set 2 | ilek
# Processing Record 2 of Set 2 | kutum
# Processing Record 3 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | xinpu
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | karasburg
# Processing Record 9 of Set 2 | vinh
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | klaksvik
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | poltavka
# Processing Record 16 of Set 2 | asasa
# Processing Record 17 of Set 2 | lethem
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | am timan
# Processing Record 21 of Set 2 | port hardy
# Processing Record 22 of Set 2 | belaya gora
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | buraydah
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | grand-santi
# Processing Record 31 of Set 2 | shache
# Processing Record 32 of Set 2 | valdez
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | hasaki
# Processing Record 35 of Set 2 | kamenka
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | grand gaube
# Processing Record 39 of Set 2 | victoria
# Processing Record 40 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | el dorado
# Processing Record 45 of Set 2 | baykit
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | saint-pierre
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | ekhabi
# Processing Record 50 of Set 2 | barra patuca
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | pangnirtung
# Processing Record 4 of Set 3 | paciran
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | yar-sale
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | southampton
# Processing Record 9 of Set 3 | sydney mines
# Processing Record 10 of Set 3 | bom jesus
# Processing Record 11 of Set 3 | erenhot
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | ust-kuyga
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | coihaique
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | ihosy
# Processing Record 18 of Set 3 | kununurra
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | vaitape
# Processing Record 22 of Set 3 | port moresby
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | laguna
# Processing Record 25 of Set 3 | mataura
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | wanlaweyn
# Processing Record 28 of Set 3 | codrington
# Processing Record 29 of Set 3 | bathsheba
# Processing Record 30 of Set 3 | san cristobal
# Processing Record 31 of Set 3 | kuching
# Processing Record 32 of Set 3 | shingu
# Processing Record 33 of Set 3 | honiara
# Processing Record 34 of Set 3 | stepnyak
# Processing Record 35 of Set 3 | wageningen
# Processing Record 36 of Set 3 | chulym
# Processing Record 37 of Set 3 | soe
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | heinola
# Processing Record 40 of Set 3 | corrente
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | chipinge
# Processing Record 43 of Set 3 | scalloway
# City not found. Skipping...
# Processing Record 44 of Set 3 | paso de carrasco
# Processing Record 45 of Set 3 | ust-barguzin
# Processing Record 46 of Set 3 | dali
# Processing Record 47 of Set 3 | caravelas
# Processing Record 48 of Set 3 | oranjemund
# Processing Record 49 of Set 3 | la macarena
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | alugan
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | lithakia
# Processing Record 6 of Set 4 | rio grande
# Processing Record 7 of Set 4 | honningsvag
# Processing Record 8 of Set 4 | marsh harbour
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 4 | constitucion
# Processing Record 12 of Set 4 | nemuro
# Processing Record 13 of Set 4 | katsuura
# Processing Record 14 of Set 4 | tucupita
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 4 | hermanus
# Processing Record 19 of Set 4 | chuy
# Processing Record 20 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 4 | nikolskoye
# Processing Record 22 of Set 4 | mendi
# Processing Record 23 of Set 4 | guamuchil
# Processing Record 24 of Set 4 | fez
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | prabumulih
# Processing Record 27 of Set 4 | pochutla
# Processing Record 28 of Set 4 | loiza
# Processing Record 29 of Set 4 | manokwari
# Processing Record 30 of Set 4 | thunder bay
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | igarka
# Processing Record 33 of Set 4 | staryy nadym
# Processing Record 34 of Set 4 | mayo
# Processing Record 35 of Set 4 | camaguey
# Processing Record 36 of Set 4 | sorland
# Processing Record 37 of Set 4 | sur
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | mago
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | veverska bityska
# Processing Record 43 of Set 4 | mount gambier
# Processing Record 44 of Set 4 | jijiga
# Processing Record 45 of Set 4 | nha trang
# Processing Record 46 of Set 4 | sabinopolis
# Processing Record 47 of Set 4 | gushikawa
# Processing Record 48 of Set 4 | mastung
# Processing Record 49 of Set 4 | san lorenzo
# Processing Record 50 of Set 4 | asau
# Processing Record 1 of Set 5 | roseburg
# Processing Record 2 of Set 5 | leh
# Processing Record 3 of Set 5 | san andres
# Processing Record 4 of Set 5 | moron
# Processing Record 5 of Set 5 | yellowknife
# Processing Record 6 of Set 5 | tukrah
# Processing Record 7 of Set 5 | cockburn town
# Processing Record 8 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | praia
# Processing Record 11 of Set 5 | taksimo
# Processing Record 12 of Set 5 | la rioja
# Processing Record 13 of Set 5 | tasiilaq
# Processing Record 14 of Set 5 | xifeng
# Processing Record 15 of Set 5 | huarmey
# Processing Record 16 of Set 5 | cherskiy
# Processing Record 17 of Set 5 | lalibela
# Processing Record 18 of Set 5 | yarada
# Processing Record 19 of Set 5 | sahrak
# City not found. Skipping...
# Processing Record 20 of Set 5 | emba
# Processing Record 21 of Set 5 | kuah
# Processing Record 22 of Set 5 | puerto escondido
# Processing Record 23 of Set 5 | portland
# Processing Record 24 of Set 5 | kapaa
# Processing Record 25 of Set 5 | venice
# Processing Record 26 of Set 5 | kaitangata
# Processing Record 27 of Set 5 | karratha
# Processing Record 28 of Set 5 | sovetskiy
# Processing Record 29 of Set 5 | poum
# Processing Record 30 of Set 5 | balud
# Processing Record 31 of Set 5 | rondonopolis
# Processing Record 32 of Set 5 | quatre cocos
# Processing Record 33 of Set 5 | ketchikan
# Processing Record 34 of Set 5 | terrassa
# Processing Record 35 of Set 5 | fort-shevchenko
# Processing Record 36 of Set 5 | balakhta
# Processing Record 37 of Set 5 | kruisfontein
# Processing Record 38 of Set 5 | puerto carreno
# Processing Record 39 of Set 5 | nouadhibou
# Processing Record 40 of Set 5 | balabac
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | dunaszentgyorgy
# Processing Record 43 of Set 5 | araouane
# Processing Record 44 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 5 | teluknaga
# Processing Record 46 of Set 5 | bitung
# Processing Record 47 of Set 5 | aksarka
# Processing Record 48 of Set 5 | sambava
# Processing Record 49 of Set 5 | khandyga
# Processing Record 50 of Set 5 | seminole
# Processing Record 1 of Set 6 | port lincoln
# Processing Record 2 of Set 6 | cap malheureux
# Processing Record 3 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 6 | altay
# Processing Record 5 of Set 6 | sitka
# Processing Record 6 of Set 6 | kautokeino
# Processing Record 7 of Set 6 | wanning
# Processing Record 8 of Set 6 | salalah
# Processing Record 9 of Set 6 | tuatapere
# Processing Record 10 of Set 6 | kalmunai
# Processing Record 11 of Set 6 | ponta do sol
# Processing Record 12 of Set 6 | tura
# Processing Record 13 of Set 6 | katherine
# Processing Record 14 of Set 6 | port hueneme
# Processing Record 15 of Set 6 | hami
# Processing Record 16 of Set 6 | aykhal
# Processing Record 17 of Set 6 | goure
# Processing Record 18 of Set 6 | cidreira
# Processing Record 19 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 20 of Set 6 | hofn
# Processing Record 21 of Set 6 | killybegs
# Processing Record 22 of Set 6 | khani
# Processing Record 23 of Set 6 | el alto
# Processing Record 24 of Set 6 | tiznit
# Processing Record 25 of Set 6 | atambua
# Processing Record 26 of Set 6 | izmit
# Processing Record 27 of Set 6 | murdochville
# Processing Record 28 of Set 6 | juba
# Processing Record 29 of Set 6 | surt
# Processing Record 30 of Set 6 | amzya
# Processing Record 31 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 6 | arraial do cabo
# Processing Record 33 of Set 6 | radnevo
# Processing Record 34 of Set 6 | oistins
# Processing Record 35 of Set 6 | navahrudak
# Processing Record 36 of Set 6 | moorhead
# Processing Record 37 of Set 6 | namatanai
# Processing Record 38 of Set 6 | makat
# Processing Record 39 of Set 6 | valleyview
# Processing Record 40 of Set 6 | golkoy
# Processing Record 41 of Set 6 | kichera
# Processing Record 42 of Set 6 | paita
# Processing Record 43 of Set 6 | atar
# Processing Record 44 of Set 6 | santa cruz
# Processing Record 45 of Set 6 | orzhytsya
# Processing Record 46 of Set 6 | soyo
# Processing Record 47 of Set 6 | abu dhabi
# Processing Record 48 of Set 6 | maniitsoq
# Processing Record 49 of Set 6 | santo domingo
# Processing Record 50 of Set 6 | lebedinyy
# Processing Record 1 of Set 7 | lompoc
# Processing Record 2 of Set 7 | santa helena de goias
# Processing Record 3 of Set 7 | general roca
# Processing Record 4 of Set 7 | zemio
# Processing Record 5 of Set 7 | burica
# City not found. Skipping...
# Processing Record 6 of Set 7 | flinders
# Processing Record 7 of Set 7 | gander
# Processing Record 8 of Set 7 | penzance
# Processing Record 9 of Set 7 | bengkulu
# Processing Record 10 of Set 7 | mogadishu
# Processing Record 11 of Set 7 | barbastro
# Processing Record 12 of Set 7 | mosjoen
# Processing Record 13 of Set 7 | bowen
# Processing Record 14 of Set 7 | cururupu
# Processing Record 15 of Set 7 | antalaha
# Processing Record 16 of Set 7 | gombe
# Processing Record 17 of Set 7 | san joaquin
# Processing Record 18 of Set 7 | oskemen
# Processing Record 19 of Set 7 | alta floresta
# Processing Record 20 of Set 7 | canatlan
# Processing Record 21 of Set 7 | talnakh
# Processing Record 22 of Set 7 | dongsheng
# Processing Record 23 of Set 7 | novovyazniki
# Processing Record 24 of Set 7 | tommot
# Processing Record 25 of Set 7 | rancho palos verdes
# Processing Record 26 of Set 7 | hobyo
# Processing Record 27 of Set 7 | port alfred
# Processing Record 28 of Set 7 | yulara
# Processing Record 29 of Set 7 | praia da vitoria
# Processing Record 30 of Set 7 | odweyne
# Processing Record 31 of Set 7 | norrtalje
# Processing Record 32 of Set 7 | kahului
# Processing Record 33 of Set 7 | san quintin
# Processing Record 34 of Set 7 | urucara
# Processing Record 35 of Set 7 | chara
# Processing Record 36 of Set 7 | lockport
# Processing Record 37 of Set 7 | saint-augustin
# Processing Record 38 of Set 7 | tocopilla
# Processing Record 39 of Set 7 | ulaanbaatar
# Processing Record 40 of Set 7 | hukuntsi
# Processing Record 41 of Set 7 | jucurutu
# Processing Record 42 of Set 7 | nome
# Processing Record 43 of Set 7 | gorodishche
# Processing Record 44 of Set 7 | mao
# Processing Record 45 of Set 7 | nouakchott
# Processing Record 46 of Set 7 | majene
# Processing Record 47 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 7 | gizo
# Processing Record 49 of Set 7 | pacific grove
# Processing Record 50 of Set 7 | tateyama
# Processing Record 1 of Set 8 | havre-saint-pierre
# Processing Record 2 of Set 8 | ituacu
# Processing Record 3 of Set 8 | sabang
# Processing Record 4 of Set 8 | karera
# Processing Record 5 of Set 8 | rock springs
# Processing Record 6 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 8 | olmos
# Processing Record 8 of Set 8 | road town
# Processing Record 9 of Set 8 | polunochnoye
# Processing Record 10 of Set 8 | scarborough
# Processing Record 11 of Set 8 | chokurdakh
# Processing Record 12 of Set 8 | lazaro cardenas
# Processing Record 13 of Set 8 | kibaek
# Processing Record 14 of Set 8 | kusk
# City not found. Skipping...
# Processing Record 15 of Set 8 | maldonado
# Processing Record 16 of Set 8 | meulaboh
# Processing Record 17 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 8 | seydi
# Processing Record 19 of Set 8 | methven
# Processing Record 20 of Set 8 | seoul
# Processing Record 21 of Set 8 | saeby
# Processing Record 22 of Set 8 | cayenne
# Processing Record 23 of Set 8 | vilani
# Processing Record 24 of Set 8 | sakakah
# Processing Record 25 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 8 | kiraoli
# Processing Record 27 of Set 8 | muswellbrook
# Processing Record 28 of Set 8 | los llanos de aridane
# Processing Record 29 of Set 8 | marystown
# Processing Record 30 of Set 8 | pringsewu
# Processing Record 31 of Set 8 | makarov
# Processing Record 32 of Set 8 | champerico
# Processing Record 33 of Set 8 | torbay
# Processing Record 34 of Set 8 | ghanzi
# Processing Record 35 of Set 8 | kedrovyy
# Processing Record 36 of Set 8 | christchurch
# Processing Record 37 of Set 8 | nioro
# Processing Record 38 of Set 8 | bud
# Processing Record 39 of Set 8 | yantai
# Processing Record 40 of Set 8 | udachnyy
# Processing Record 41 of Set 8 | lavrentiya
# Processing Record 42 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 8 | santa cruz de tenerife
# Processing Record 44 of Set 8 | norman wells
# Processing Record 45 of Set 8 | letham
# Processing Record 46 of Set 8 | homer
# Processing Record 47 of Set 8 | san jeronimo
# Processing Record 48 of Set 8 | sigli
# Processing Record 49 of Set 8 | vanimo
# Processing Record 50 of Set 8 | margate
# Processing Record 1 of Set 9 | esperance
# Processing Record 2 of Set 9 | grand island
# Processing Record 3 of Set 9 | atagay
# Processing Record 4 of Set 9 | talara
# Processing Record 5 of Set 9 | boende
# Processing Record 6 of Set 9 | coquimbo
# Processing Record 7 of Set 9 | japura
# Processing Record 8 of Set 9 | nyurba
# Processing Record 9 of Set 9 | pisco
# Processing Record 10 of Set 9 | ilulissat
# Processing Record 11 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 9 | vikhorevka
# Processing Record 13 of Set 9 | biankouma
# Processing Record 14 of Set 9 | isla vista
# Processing Record 15 of Set 9 | linhares
# Processing Record 16 of Set 9 | hinton
# Processing Record 17 of Set 9 | sola
# Processing Record 18 of Set 9 | noyabrsk
# Processing Record 19 of Set 9 | inzer
# Processing Record 20 of Set 9 | vao
# Processing Record 21 of Set 9 | albury
# Processing Record 22 of Set 9 | erdenet
# Processing Record 23 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 24 of Set 9 | vila velha
# Processing Record 25 of Set 9 | puerto ayacucho
# Processing Record 26 of Set 9 | luoyang
# Processing Record 27 of Set 9 | sibu
# Processing Record 28 of Set 9 | tall kayf
# Processing Record 29 of Set 9 | nkan
# Processing Record 30 of Set 9 | dingle
# Processing Record 31 of Set 9 | cape canaveral
# Processing Record 32 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 9 | ixtapa
# Processing Record 34 of Set 9 | george town
# Processing Record 35 of Set 9 | bubaque
# Processing Record 36 of Set 9 | kavieng
# Processing Record 37 of Set 9 | arman
# Processing Record 38 of Set 9 | jalu
# Processing Record 39 of Set 9 | mikhaylovka
# Processing Record 40 of Set 9 | birjand
# Processing Record 41 of Set 9 | ballitoville
# Processing Record 42 of Set 9 | jinchang
# Processing Record 43 of Set 9 | berekum
# Processing Record 44 of Set 9 | shaoyang
# Processing Record 45 of Set 9 | manggar
# Processing Record 46 of Set 9 | pontian kecil
# Processing Record 47 of Set 9 | taoudenni
# Processing Record 48 of Set 9 | sioux lookout
# Processing Record 49 of Set 9 | cruz alta
# Processing Record 50 of Set 9 | beringovskiy
# Processing Record 1 of Set 10 | qaqortoq
# Processing Record 2 of Set 10 | tiarei
# Processing Record 3 of Set 10 | panjab
# Processing Record 4 of Set 10 | termoli
# Processing Record 5 of Set 10 | baruun-urt
# Processing Record 6 of Set 10 | chitral
# Processing Record 7 of Set 10 | bukachacha
# Processing Record 8 of Set 10 | paamiut
# Processing Record 9 of Set 10 | bonavista
# Processing Record 10 of Set 10 | dubti
# Processing Record 11 of Set 10 | kanigoro
# Processing Record 12 of Set 10 | lata
# Processing Record 13 of Set 10 | asyut
# Processing Record 14 of Set 10 | batagay-alyta
# Processing Record 15 of Set 10 | boffa
# Processing Record 16 of Set 10 | isangel
# Processing Record 17 of Set 10 | isabela
# Processing Record 18 of Set 10 | quetzaltepec
# City not found. Skipping...
# Processing Record 19 of Set 10 | port keats
# Processing Record 20 of Set 10 | lincoln
# Processing Record 21 of Set 10 | wasilla
# Processing Record 22 of Set 10 | richards bay
# Processing Record 23 of Set 10 | cabinda
# Processing Record 24 of Set 10 | kungurtug
# Processing Record 25 of Set 10 | caohai
# Processing Record 26 of Set 10 | novaya igirma
# Processing Record 27 of Set 10 | provideniya
# Processing Record 28 of Set 10 | eureka
# Processing Record 29 of Set 10 | dayong
# Processing Record 30 of Set 10 | touros
# Processing Record 31 of Set 10 | henties bay
# Processing Record 32 of Set 10 | ankpa
# Processing Record 33 of Set 10 | swellendam
# Processing Record 34 of Set 10 | cozumel
# Processing Record 35 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 10 | innisfail
# Processing Record 37 of Set 10 | marzuq
# Processing Record 38 of Set 10 | taltal
# Processing Record 39 of Set 10 | opole
# Processing Record 40 of Set 10 | gondar
# Processing Record 41 of Set 10 | la ronge
# Processing Record 42 of Set 10 | goderich
# Processing Record 43 of Set 10 | obo
# Processing Record 44 of Set 10 | antsohihy
# Processing Record 45 of Set 10 | fort nelson
# Processing Record 46 of Set 10 | yarkovo
# Processing Record 47 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 10 | bambanglipuro
# Processing Record 49 of Set 10 | neiba
# Processing Record 50 of Set 10 | necochea
# Processing Record 1 of Set 11 | crestview
# Processing Record 2 of Set 11 | kiama
# Processing Record 3 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 11 | takoradi
# Processing Record 5 of Set 11 | batemans bay
# Processing Record 6 of Set 11 | hudson bay
# Processing Record 7 of Set 11 | gallipoli
# Processing Record 8 of Set 11 | bandarbeyla
# Processing Record 9 of Set 11 | kulhudhuffushi
# Processing Record 10 of Set 11 | fernie
# Processing Record 11 of Set 11 | sinnamary
# Processing Record 12 of Set 11 | berdigestyakh
# Processing Record 13 of Set 11 | la asuncion
# Processing Record 14 of Set 11 | netivot
# Processing Record 15 of Set 11 | panzhihua
# Processing Record 16 of Set 11 | aden
# Processing Record 17 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 11 | maumere
# Processing Record 19 of Set 11 | nuuk
# Processing Record 20 of Set 11 | porto velho
# Processing Record 21 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 11 | lubango
# Processing Record 23 of Set 11 | blagodarnyy
# Processing Record 24 of Set 11 | vanderhoof
# Processing Record 25 of Set 11 | bontang
# Processing Record 26 of Set 11 | pincher creek
# Processing Record 27 of Set 11 | benton harbor
# Processing Record 28 of Set 11 | komsomolskiy
# Processing Record 29 of Set 11 | vostok
# Processing Record 30 of Set 11 | mozarlandia
# Processing Record 31 of Set 11 | ayagoz
# Processing Record 32 of Set 11 | casa grande
# Processing Record 33 of Set 11 | inta
# Processing Record 34 of Set 11 | padang
# Processing Record 35 of Set 11 | nagato
# Processing Record 36 of Set 11 | vestmanna
# Processing Record 37 of Set 11 | timra
# Processing Record 38 of Set 11 | kralendijk
# Processing Record 39 of Set 11 | mehran
# Processing Record 40 of Set 11 | severnyy
# Processing Record 41 of Set 11 | husavik
# Processing Record 42 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 43 of Set 11 | camalu
# Processing Record 44 of Set 11 | neuquen
# Processing Record 45 of Set 11 | rundu
# Processing Record 46 of Set 11 | green river
# Processing Record 47 of Set 11 | port augusta
# Processing Record 48 of Set 11 | alofi
# Processing Record 49 of Set 11 | zambezi
# Processing Record 50 of Set 11 | auki
# Processing Record 1 of Set 12 | harrismith
# Processing Record 2 of Set 12 | havelock
# Processing Record 3 of Set 12 | fernley
# Processing Record 4 of Set 12 | kloulklubed
# Processing Record 5 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 12 | danville
# Processing Record 7 of Set 12 | naze
# Processing Record 8 of Set 12 | karla
# Processing Record 9 of Set 12 | bilibino
# Processing Record 10 of Set 12 | broken hill
# Processing Record 11 of Set 12 | gualeguay
# Processing Record 12 of Set 12 | aloleng
# Processing Record 13 of Set 12 | khasan
# Processing Record 14 of Set 12 | pindobacu
# Processing Record 15 of Set 12 | ardino
# Processing Record 16 of Set 12 | manzanillo
# Processing Record 17 of Set 12 | monroe
# Processing Record 18 of Set 12 | kavaratti
# Processing Record 19 of Set 12 | tigil
# Processing Record 20 of Set 12 | alexandria
# Processing Record 21 of Set 12 | mandiana
# Processing Record 22 of Set 12 | broome
# Processing Record 23 of Set 12 | wencheng
# Processing Record 24 of Set 12 | totness
# Processing Record 25 of Set 12 | labuhan
# Processing Record 26 of Set 12 | teya
# Processing Record 27 of Set 12 | svolvaer
# Processing Record 28 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 12 | ewa beach
# Processing Record 30 of Set 12 | cleveland
# Processing Record 31 of Set 12 | baiquan
# Processing Record 32 of Set 12 | mingshui
# Processing Record 33 of Set 12 | ulefoss
# Processing Record 34 of Set 12 | leningradskiy
# Processing Record 35 of Set 12 | warwick
# Processing Record 36 of Set 12 | bjorkelangen
# Processing Record 37 of Set 12 | tessalit
# Processing Record 38 of Set 12 | koumac
# Processing Record 39 of Set 12 | svetlaya
# Processing Record 40 of Set 12 | spring valley
# Processing Record 41 of Set 12 | benghazi
# Processing Record 42 of Set 12 | ulladulla
# Processing Record 43 of Set 12 | voskresenskoye
# Processing Record 44 of Set 12 | iwanai
# Processing Record 45 of Set 12 | ponta delgada
# Processing Record 46 of Set 12 | norcross
# Processing Record 47 of Set 12 | jacmel
# Processing Record 48 of Set 12 | hamilton
# Processing Record 49 of Set 12 | sao miguel do araguaia
# Processing Record 50 of Set 12 | saint-pacome
# City not found. Skipping...
# Processing Record 1 of Set 13 | mericleri
# City not found. Skipping...
# Processing Record 2 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 13 | graciano sanchez
# Processing Record 4 of Set 13 | sada
# Processing Record 5 of Set 13 | moussoro
# Processing Record 6 of Set 13 | parfenyevo
# Processing Record 7 of Set 13 | olafsvik
# Processing Record 8 of Set 13 | coahuayana
# Processing Record 9 of Set 13 | ugoofaaru
# Processing Record 10 of Set 13 | taywarah
# Processing Record 11 of Set 13 | tilichiki
# Processing Record 12 of Set 13 | bar harbor
# Processing Record 13 of Set 13 | belmonte
# Processing Record 14 of Set 13 | anzio
# Processing Record 15 of Set 13 | kamskiye polyany
# Processing Record 16 of Set 13 | simpsonville
# Processing Record 17 of Set 13 | plettenberg bay
# Processing Record 18 of Set 13 | arauco
# Processing Record 19 of Set 13 | kenai
# Processing Record 20 of Set 13 | paramonga
# Processing Record 21 of Set 13 | burnie
# Processing Record 22 of Set 13 | calvinia
# Processing Record 23 of Set 13 | pasighat
# Processing Record 24 of Set 13 | kieta
# Processing Record 25 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 26 of Set 13 | sergeyevka
# Processing Record 27 of Set 13 | ipixuna
# Processing Record 28 of Set 13 | clearwater
# Processing Record 29 of Set 13 | sohag
# Processing Record 30 of Set 13 | moses lake
# Processing Record 31 of Set 13 | varde
# Processing Record 32 of Set 13 | kandrian
# Processing Record 33 of Set 13 | beloha
# Processing Record 34 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 13 | gasa
# Processing Record 36 of Set 13 | esqueda
# Processing Record 37 of Set 13 | itarema
# Processing Record 38 of Set 13 | straumen
# Processing Record 39 of Set 13 | sargatskoye
# Processing Record 40 of Set 13 | langarud
# Processing Record 41 of Set 13 | shellbrook
# Processing Record 42 of Set 13 | kaduna
# Processing Record 43 of Set 13 | skibbereen
# Processing Record 44 of Set 13 | cabra
# Processing Record 45 of Set 13 | opuwo
# Processing Record 46 of Set 13 | shakhrinau
# City not found. Skipping...
# Processing Record 47 of Set 13 | saurimo
# Processing Record 48 of Set 13 | harper
# Processing Record 49 of Set 13 | manono
# Processing Record 50 of Set 13 | sumbe
# Processing Record 1 of Set 14 | sala consilina
# Processing Record 2 of Set 14 | rapid valley
# Processing Record 3 of Set 14 | nueva loja
# Processing Record 4 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 14 | pathein
# Processing Record 6 of Set 14 | kupang
# Processing Record 7 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 14 | ahuimanu
# Processing Record 9 of Set 14 | ayan
# Processing Record 10 of Set 14 | port blair
# Processing Record 11 of Set 14 | beckley
# Processing Record 12 of Set 14 | melville
# Processing Record 13 of Set 14 | khartoum
# Processing Record 14 of Set 14 | lagos
# Processing Record 15 of Set 14 | hualmay
# Processing Record 16 of Set 14 | rosetta
# Processing Record 17 of Set 14 | ko samui
# Processing Record 18 of Set 14 | pemangkat
# Processing Record 19 of Set 14 | guangyuan
# Processing Record 20 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 21 of Set 14 | presidencia roque saenz pena
# Processing Record 22 of Set 14 | omsukchan
# Processing Record 23 of Set 14 | baoqing
# Processing Record 24 of Set 14 | omboue
# Processing Record 25 of Set 14 | ahipara
# Processing Record 26 of Set 14 | waspan
# Processing Record 27 of Set 14 | jacqueville
# Processing Record 28 of Set 14 | kaeng khoi
# Processing Record 29 of Set 14 | doha
# Processing Record 30 of Set 14 | cap-aux-meules
# Processing Record 31 of Set 14 | dukat
# Processing Record 32 of Set 14 | truth or consequences
# Processing Record 33 of Set 14 | yatou
# Processing Record 34 of Set 14 | banyo
# Processing Record 35 of Set 14 | salinas
# Processing Record 36 of Set 14 | morant bay
# Processing Record 37 of Set 14 | rocha
# Processing Record 38 of Set 14 | wilmington
# Processing Record 39 of Set 14 | kozhevnikovo
# Processing Record 40 of Set 14 | moskovskiy
# Processing Record 41 of Set 14 | sayat
# Processing Record 42 of Set 14 | malia
# Processing Record 43 of Set 14 | turkistan
# Processing Record 44 of Set 14 | synya
# Processing Record 45 of Set 14 | banjar
# Processing Record 46 of Set 14 | saint-ambroise
# Processing Record 47 of Set 14 | tolmachevo
# Processing Record 48 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 49 of Set 14 | rockland
# Processing Record 50 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 15 | iskateley
# Processing Record 2 of Set 15 | kaniama
# Processing Record 3 of Set 15 | martinsville
# Processing Record 4 of Set 15 | faya
# Processing Record 5 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 15 | vaasa
# Processing Record 7 of Set 15 | tamandare
# Processing Record 8 of Set 15 | lasa
# Processing Record 9 of Set 15 | ambulu
# Processing Record 10 of Set 15 | hervey bay
# Processing Record 11 of Set 15 | ostrovnoy
# Processing Record 12 of Set 15 | sorong
# Processing Record 13 of Set 15 | vagur
# Processing Record 14 of Set 15 | menongue
# Processing Record 15 of Set 15 | bridlington
# Processing Record 16 of Set 15 | taiyuan
# Processing Record 17 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 15 | kudahuvadhoo
# Processing Record 19 of Set 15 | abapo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 665

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Qaanaaq      GL  77.4840  -69.3632      0.54        91         100
# 1             Abha      SA  18.2164   42.5053     59.00        67          40
# 2            Maraa      BR  -1.8333  -65.3667     77.22        94          79
# 3    Srednekolymsk      RU  67.4500  153.6833     25.27        72         100
# 4            Yumen      CN  40.2833   97.2000     47.64        17          98
# 5     Punta Arenas      CL -53.1500  -70.9167     51.80        62          75
# 6           Hobart      AU -42.8794  147.3294     57.20        58          75
# 7  Bambous Virieux      MU -20.3428   57.7575     78.01        94          75
# 8            Kidal      ML  18.4411    1.4078     90.18         6         100
# 9          Ushuaia      AR -54.8000  -68.3000     55.40        47          75
#
#    Wind Speed Weather Description
# 0        3.31     overcast clouds
# 1       16.11          light rain
# 2        1.74       broken clouds
# 3       13.76     overcast clouds
# 4        3.11     overcast clouds
# 5        6.91       broken clouds
# 6       12.66       broken clouds
# 7        3.44       broken clouds
# 8        4.92     overcast clouds
# 9       10.36       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "./WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
