# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm output count.
len(cities)
# Out:
# 743

# %%
# Base URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7130ff2caeb6d2724a6cefcb729b6590

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
#       print(city_weather)
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        #print("lat", city_weather["coord"]["lat"])
        city_lng = city_weather["coord"]["lon"]
        #print("longitude", city_weather["coord"]["lon"])
        city_max_temp = city_weather["main"]["temp_max"]
        #print("max temp", city_weather["main"]["temp_max"])
        city_humidity = city_weather["main"]["humidity"]
        #print("humidity", city_weather["main"]["humidity"])
        city_clouds = city_weather["clouds"]["all"]
        #print("clouds", city_weather["clouds"]["all"])
        city_wind = city_weather["wind"]["speed"]
        #print("wind", city_weather["wind"]["speed"])
        city_weather_description = city_weather["weather"][0]["description"]
        #print("description", city_weather["weather"][0]["description"])
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #print(city_date)
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country, 
                          "Lat": city_lat,
                           "Lng": city_lng,
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Weather Description": city_weather_description,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | namatanai
# Processing Record 2 of Set 1 | tuy hoa
# Processing Record 3 of Set 1 | bonthe
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | aldan
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | zhezkazgan
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | saint-georges
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | katobu
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | borovoy
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | yenagoa
# Processing Record 22 of Set 1 | marawi
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | requena
# Processing Record 27 of Set 1 | muros
# Processing Record 28 of Set 1 | djibo
# Processing Record 29 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | lyubim
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | udachnyy
# Processing Record 40 of Set 1 | henties bay
# Processing Record 41 of Set 1 | sao joao da barra
# Processing Record 42 of Set 1 | severo-yeniseyskiy
# Processing Record 43 of Set 1 | coquimbo
# Processing Record 44 of Set 1 | santa cruz
# Processing Record 45 of Set 1 | voh
# Processing Record 46 of Set 1 | amguri
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | nizwa
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | asheville
# Processing Record 2 of Set 2 | leningradskiy
# Processing Record 3 of Set 2 | zhangjiakou
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | erdemli
# Processing Record 6 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 2 | belaya gora
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | san juan
# Processing Record 10 of Set 2 | verkhnyaya inta
# Processing Record 11 of Set 2 | isangel
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | mount gambier
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | puerto narino
# Processing Record 16 of Set 2 | verkhnevilyuysk
# Processing Record 17 of Set 2 | fort nelson
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | nelson bay
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | sidrolandia
# Processing Record 24 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 2 | salur
# Processing Record 26 of Set 2 | kropotkin
# Processing Record 27 of Set 2 | carpinteria
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | komsomolskiy
# Processing Record 32 of Set 2 | burley
# Processing Record 33 of Set 2 | kahului
# Processing Record 34 of Set 2 | mount isa
# Processing Record 35 of Set 2 | hannibal
# Processing Record 36 of Set 2 | grand gaube
# Processing Record 37 of Set 2 | taoudenni
# Processing Record 38 of Set 2 | vila velha
# Processing Record 39 of Set 2 | walvis bay
# Processing Record 40 of Set 2 | rodrigues alves
# Processing Record 41 of Set 2 | vrangel
# Processing Record 42 of Set 2 | kushima
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | wattegama
# Processing Record 45 of Set 2 | casma
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | bilma
# Processing Record 49 of Set 2 | rzhaksa
# Processing Record 50 of Set 2 | busselton
# Processing Record 1 of Set 3 | flinders
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | valparaiso
# Processing Record 4 of Set 3 | kalofer
# Processing Record 5 of Set 3 | avera
# Processing Record 6 of Set 3 | ikalamavony
# Processing Record 7 of Set 3 | moron
# Processing Record 8 of Set 3 | manjacaze
# Processing Record 9 of Set 3 | vao
# Processing Record 10 of Set 3 | srednekolymsk
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | pisco
# Processing Record 15 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 3 | dymer
# Processing Record 17 of Set 3 | merauke
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | takoradi
# Processing Record 21 of Set 3 | mana
# Processing Record 22 of Set 3 | fairbanks
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | hueyapan
# Processing Record 26 of Set 3 | pringsewu
# Processing Record 27 of Set 3 | charters towers
# Processing Record 28 of Set 3 | albany
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | malanje
# Processing Record 32 of Set 3 | quiindy
# Processing Record 33 of Set 3 | coruripe
# Processing Record 34 of Set 3 | taltal
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | bahia de caraquez
# Processing Record 39 of Set 3 | ondangwa
# Processing Record 40 of Set 3 | nikolskoye
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | svetlyy
# Processing Record 44 of Set 3 | georgetown
# Processing Record 45 of Set 3 | auki
# Processing Record 46 of Set 3 | luderitz
# Processing Record 47 of Set 3 | port-gentil
# Processing Record 48 of Set 3 | tucuman
# Processing Record 49 of Set 3 | tarjan
# Processing Record 50 of Set 3 | kodinsk
# Processing Record 1 of Set 4 | saint-augustin
# Processing Record 2 of Set 4 | erzin
# Processing Record 3 of Set 4 | puerto escondido
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | paita
# Processing Record 6 of Set 4 | mareeba
# Processing Record 7 of Set 4 | galle
# Processing Record 8 of Set 4 | tigil
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | murray bridge
# Processing Record 11 of Set 4 | southbridge
# Processing Record 12 of Set 4 | gazli
# Processing Record 13 of Set 4 | bambous virieux
# Processing Record 14 of Set 4 | samarai
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | mezen
# Processing Record 17 of Set 4 | tazovskiy
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | mazagao
# Processing Record 20 of Set 4 | puerto del rosario
# Processing Record 21 of Set 4 | berlevag
# Processing Record 22 of Set 4 | margate
# Processing Record 23 of Set 4 | te anau
# Processing Record 24 of Set 4 | tura
# Processing Record 25 of Set 4 | metro
# Processing Record 26 of Set 4 | lakes entrance
# Processing Record 27 of Set 4 | hasaki
# Processing Record 28 of Set 4 | den helder
# Processing Record 29 of Set 4 | aklavik
# Processing Record 30 of Set 4 | nikita
# Processing Record 31 of Set 4 | hambantota
# Processing Record 32 of Set 4 | westport
# Processing Record 33 of Set 4 | geraldton
# Processing Record 34 of Set 4 | manati
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | yarada
# Processing Record 37 of Set 4 | dunedin
# Processing Record 38 of Set 4 | kaitangata
# Processing Record 39 of Set 4 | anadyr
# Processing Record 40 of Set 4 | sao paulo de olivenca
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | chenzhou
# Processing Record 43 of Set 4 | saint george
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | richards bay
# Processing Record 46 of Set 4 | murgab
# Processing Record 47 of Set 4 | port alfred
# Processing Record 48 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | junagarh
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | itarema
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | phek
# Processing Record 6 of Set 5 | sim
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | saucillo
# Processing Record 9 of Set 5 | gazi
# Processing Record 10 of Set 5 | mogadishu
# Processing Record 11 of Set 5 | tautira
# Processing Record 12 of Set 5 | maningrida
# Processing Record 13 of Set 5 | klaksvik
# Processing Record 14 of Set 5 | aksarayskiy
# Processing Record 15 of Set 5 | snasa
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | whitehorse
# Processing Record 18 of Set 5 | buritis
# Processing Record 19 of Set 5 | lompoc
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | alofi
# Processing Record 22 of Set 5 | vyshneve
# Processing Record 23 of Set 5 | constitucion
# Processing Record 24 of Set 5 | half moon bay
# Processing Record 25 of Set 5 | trofors
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | ugoofaaru
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 5 | ryotsu
# Processing Record 32 of Set 5 | garmsar
# Processing Record 33 of Set 5 | eregli
# Processing Record 34 of Set 5 | castro
# Processing Record 35 of Set 5 | ayan
# Processing Record 36 of Set 5 | caravelas
# Processing Record 37 of Set 5 | brae
# Processing Record 38 of Set 5 | bethanien
# Processing Record 39 of Set 5 | muhos
# Processing Record 40 of Set 5 | hohhot
# Processing Record 41 of Set 5 | bilibino
# Processing Record 42 of Set 5 | catanzaro
# Processing Record 43 of Set 5 | beira
# Processing Record 44 of Set 5 | gilbues
# Processing Record 45 of Set 5 | korla
# Processing Record 46 of Set 5 | nabire
# Processing Record 47 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 5 | cukai
# Processing Record 49 of Set 5 | qaanaaq
# Processing Record 50 of Set 5 | san ramon
# Processing Record 1 of Set 6 | demidov
# Processing Record 2 of Set 6 | laurel
# Processing Record 3 of Set 6 | madimba
# Processing Record 4 of Set 6 | aden
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | lodwar
# Processing Record 7 of Set 6 | necochea
# Processing Record 8 of Set 6 | sinnamary
# Processing Record 9 of Set 6 | sompeta
# Processing Record 10 of Set 6 | port hardy
# Processing Record 11 of Set 6 | yar-sale
# Processing Record 12 of Set 6 | nanortalik
# Processing Record 13 of Set 6 | phangnga
# Processing Record 14 of Set 6 | fortuna
# Processing Record 15 of Set 6 | tasiilaq
# Processing Record 16 of Set 6 | muravlenko
# Processing Record 17 of Set 6 | lata
# Processing Record 18 of Set 6 | del rio
# Processing Record 19 of Set 6 | lavrentiya
# Processing Record 20 of Set 6 | san carlos de bariloche
# Processing Record 21 of Set 6 | bell ville
# Processing Record 22 of Set 6 | ancud
# Processing Record 23 of Set 6 | copiapo
# Processing Record 24 of Set 6 | makasar
# Processing Record 25 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 6 | solnechnyy
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | sobolevo
# Processing Record 29 of Set 6 | coria
# Processing Record 30 of Set 6 | broken hill
# Processing Record 31 of Set 6 | buala
# Processing Record 32 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 6 | bakchar
# Processing Record 34 of Set 6 | halifax
# Processing Record 35 of Set 6 | yulara
# Processing Record 36 of Set 6 | krasnogorodsk
# Processing Record 37 of Set 6 | flin flon
# Processing Record 38 of Set 6 | san jose
# Processing Record 39 of Set 6 | khani
# Processing Record 40 of Set 6 | loubomo
# Processing Record 41 of Set 6 | anshun
# Processing Record 42 of Set 6 | grindavik
# Processing Record 43 of Set 6 | kuching
# Processing Record 44 of Set 6 | bria
# Processing Record 45 of Set 6 | alice town
# Processing Record 46 of Set 6 | amahai
# Processing Record 47 of Set 6 | batagay-alyta
# Processing Record 48 of Set 6 | shihezi
# Processing Record 49 of Set 6 | mehamn
# Processing Record 50 of Set 6 | ostersund
# Processing Record 1 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 2 of Set 7 | nampula
# Processing Record 3 of Set 7 | vostok
# Processing Record 4 of Set 7 | san felipe
# Processing Record 5 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 7 | kiruna
# Processing Record 7 of Set 7 | paracuru
# Processing Record 8 of Set 7 | yeppoon
# Processing Record 9 of Set 7 | husavik
# Processing Record 10 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 7 | lontzen
# Processing Record 12 of Set 7 | erenhot
# Processing Record 13 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | khawhai
# Processing Record 16 of Set 7 | fukue
# Processing Record 17 of Set 7 | chapais
# Processing Record 18 of Set 7 | stodolishche
# Processing Record 19 of Set 7 | westerland
# Processing Record 20 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 21 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 7 | omsukchan
# Processing Record 24 of Set 7 | cabo san lucas
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | saint anthony
# Processing Record 27 of Set 7 | sibolga
# Processing Record 28 of Set 7 | rocha
# Processing Record 29 of Set 7 | vestmanna
# Processing Record 30 of Set 7 | suamico
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | ban nahin
# Processing Record 33 of Set 7 | inuvik
# Processing Record 34 of Set 7 | cairns
# Processing Record 35 of Set 7 | sao joao do paraiso
# Processing Record 36 of Set 7 | villa bruzual
# Processing Record 37 of Set 7 | mandalgovi
# Processing Record 38 of Set 7 | chipinge
# Processing Record 39 of Set 7 | pontes e lacerda
# Processing Record 40 of Set 7 | ajdabiya
# Processing Record 41 of Set 7 | kaeo
# Processing Record 42 of Set 7 | corpus christi
# Processing Record 43 of Set 7 | qasigiannguit
# Processing Record 44 of Set 7 | moree
# Processing Record 45 of Set 7 | atlantic city
# Processing Record 46 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 7 | sokolac
# Processing Record 48 of Set 7 | dzaoudzi
# Processing Record 49 of Set 7 | ambilobe
# Processing Record 50 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 8 | taksimo
# Processing Record 2 of Set 8 | gweta
# Processing Record 3 of Set 8 | ballina
# Processing Record 4 of Set 8 | colac
# Processing Record 5 of Set 8 | vanavara
# Processing Record 6 of Set 8 | padang
# Processing Record 7 of Set 8 | ciudad dario
# Processing Record 8 of Set 8 | east london
# Processing Record 9 of Set 8 | murgasi
# City not found. Skipping...
# Processing Record 10 of Set 8 | dali
# Processing Record 11 of Set 8 | shubarkuduk
# Processing Record 12 of Set 8 | cravo norte
# Processing Record 13 of Set 8 | chicama
# Processing Record 14 of Set 8 | barsovo
# Processing Record 15 of Set 8 | asfi
# Processing Record 16 of Set 8 | atyrau
# Processing Record 17 of Set 8 | kristiansund
# Processing Record 18 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 8 | saldanha
# Processing Record 20 of Set 8 | guatire
# Processing Record 21 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | laives
# Processing Record 24 of Set 8 | mastic beach
# Processing Record 25 of Set 8 | champerico
# Processing Record 26 of Set 8 | buraydah
# Processing Record 27 of Set 8 | sakhipur
# Processing Record 28 of Set 8 | parati
# Processing Record 29 of Set 8 | kenai
# Processing Record 30 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 31 of Set 8 | price
# Processing Record 32 of Set 8 | hendijan
# City not found. Skipping...
# Processing Record 33 of Set 8 | taphan hin
# Processing Record 34 of Set 8 | uglegorsk
# Processing Record 35 of Set 8 | provideniya
# Processing Record 36 of Set 8 | macau
# Processing Record 37 of Set 8 | sitka
# Processing Record 38 of Set 8 | boffa
# Processing Record 39 of Set 8 | coahuayana
# Processing Record 40 of Set 8 | bridlington
# Processing Record 41 of Set 8 | yerbogachen
# Processing Record 42 of Set 8 | providencia
# Processing Record 43 of Set 8 | saravan
# Processing Record 44 of Set 8 | krasnoselkup
# Processing Record 45 of Set 8 | maua
# Processing Record 46 of Set 8 | moose jaw
# Processing Record 47 of Set 8 | san cristobal
# Processing Record 48 of Set 8 | codrington
# Processing Record 49 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 8 | katsuura
# Processing Record 1 of Set 9 | uray
# Processing Record 2 of Set 9 | gualeguay
# Processing Record 3 of Set 9 | soe
# Processing Record 4 of Set 9 | dargaville
# Processing Record 5 of Set 9 | vredendal
# Processing Record 6 of Set 9 | beringovskiy
# Processing Record 7 of Set 9 | sisimiut
# Processing Record 8 of Set 9 | glen allen
# Processing Record 9 of Set 9 | abu dhabi
# Processing Record 10 of Set 9 | kamenka
# Processing Record 11 of Set 9 | narsaq
# Processing Record 12 of Set 9 | ust-tsilma
# Processing Record 13 of Set 9 | gravdal
# Processing Record 14 of Set 9 | sigerfjord
# City not found. Skipping...
# Processing Record 15 of Set 9 | linguere
# Processing Record 16 of Set 9 | esna
# Processing Record 17 of Set 9 | hofn
# Processing Record 18 of Set 9 | boguchany
# Processing Record 19 of Set 9 | ambon
# Processing Record 20 of Set 9 | santiago de cao
# Processing Record 21 of Set 9 | coihaique
# Processing Record 22 of Set 9 | mbini
# Processing Record 23 of Set 9 | sao pedro do sul
# Processing Record 24 of Set 9 | morros
# Processing Record 25 of Set 9 | lethem
# Processing Record 26 of Set 9 | bima
# Processing Record 27 of Set 9 | manzanillo
# Processing Record 28 of Set 9 | norman wells
# Processing Record 29 of Set 9 | haines junction
# Processing Record 30 of Set 9 | hamilton
# Processing Record 31 of Set 9 | sao miguel do araguaia
# Processing Record 32 of Set 9 | lloydminster
# Processing Record 33 of Set 9 | tikheron
# City not found. Skipping...
# Processing Record 34 of Set 9 | penzance
# Processing Record 35 of Set 9 | chulym
# Processing Record 36 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 9 | aleksandrov gay
# Processing Record 38 of Set 9 | tual
# Processing Record 39 of Set 9 | bhalki
# Processing Record 40 of Set 9 | maraa
# Processing Record 41 of Set 9 | umm kaddadah
# Processing Record 42 of Set 9 | nouakchott
# Processing Record 43 of Set 9 | palencia
# Processing Record 44 of Set 9 | acacoyagua
# Processing Record 45 of Set 9 | alyangula
# Processing Record 46 of Set 9 | terre haute
# Processing Record 47 of Set 9 | zarate
# Processing Record 48 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 9 | port blair
# Processing Record 50 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 10 | lamar
# Processing Record 2 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 10 | nouadhibou
# Processing Record 4 of Set 10 | aykhal
# Processing Record 5 of Set 10 | tuktoyaktuk
# Processing Record 6 of Set 10 | osoyoos
# Processing Record 7 of Set 10 | porto novo
# Processing Record 8 of Set 10 | bogatyye saby
# Processing Record 9 of Set 10 | kardla
# Processing Record 10 of Set 10 | bud
# Processing Record 11 of Set 10 | hay river
# Processing Record 12 of Set 10 | sakakah
# Processing Record 13 of Set 10 | veraval
# Processing Record 14 of Set 10 | japura
# Processing Record 15 of Set 10 | vung tau
# Processing Record 16 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 10 | yantal
# Processing Record 18 of Set 10 | guelengdeng
# City not found. Skipping...
# Processing Record 19 of Set 10 | hulan
# Processing Record 20 of Set 10 | kanturk
# Processing Record 21 of Set 10 | yerofey pavlovich
# Processing Record 22 of Set 10 | matara
# Processing Record 23 of Set 10 | buchanan
# Processing Record 24 of Set 10 | viedma
# Processing Record 25 of Set 10 | mulege
# Processing Record 26 of Set 10 | golden
# Processing Record 27 of Set 10 | morondava
# Processing Record 28 of Set 10 | sabirabad
# Processing Record 29 of Set 10 | denia
# Processing Record 30 of Set 10 | asau
# Processing Record 31 of Set 10 | peniche
# Processing Record 32 of Set 10 | turukhansk
# Processing Record 33 of Set 10 | cap malheureux
# Processing Record 34 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 10 | capiibary
# Processing Record 36 of Set 10 | bowen
# Processing Record 37 of Set 10 | illapel
# Processing Record 38 of Set 10 | mingaora
# Processing Record 39 of Set 10 | danielskuil
# Processing Record 40 of Set 10 | severo-kurilsk
# Processing Record 41 of Set 10 | faanui
# Processing Record 42 of Set 10 | chernyshevsk
# Processing Record 43 of Set 10 | russell
# Processing Record 44 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 10 | tambun
# Processing Record 46 of Set 10 | naze
# Processing Record 47 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 10 | sembe
# Processing Record 49 of Set 10 | abu zabad
# Processing Record 50 of Set 10 | hammerfest
# Processing Record 1 of Set 11 | pangai
# Processing Record 2 of Set 11 | emba
# Processing Record 3 of Set 11 | sistranda
# Processing Record 4 of Set 11 | noumea
# Processing Record 5 of Set 11 | riachao das neves
# Processing Record 6 of Set 11 | akdepe
# Processing Record 7 of Set 11 | sorkjosen
# Processing Record 8 of Set 11 | artvin
# Processing Record 9 of Set 11 | loei
# Processing Record 10 of Set 11 | baft
# Processing Record 11 of Set 11 | ossora
# Processing Record 12 of Set 11 | zhigansk
# Processing Record 13 of Set 11 | ketchikan
# Processing Record 14 of Set 11 | sayyan
# Processing Record 15 of Set 11 | waingapu
# Processing Record 16 of Set 11 | muisne
# Processing Record 17 of Set 11 | simao
# Processing Record 18 of Set 11 | saint-francois
# Processing Record 19 of Set 11 | vari
# Processing Record 20 of Set 11 | marrakesh
# Processing Record 21 of Set 11 | novikovo
# Processing Record 22 of Set 11 | cabedelo
# Processing Record 23 of Set 11 | port moresby
# Processing Record 24 of Set 11 | khandbari
# Processing Record 25 of Set 11 | raudeberg
# Processing Record 26 of Set 11 | cusco
# Processing Record 27 of Set 11 | ananas
# Processing Record 28 of Set 11 | contramaestre
# Processing Record 29 of Set 11 | imbituba
# Processing Record 30 of Set 11 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 11 | sept-iles
# Processing Record 32 of Set 11 | derzhavinsk
# Processing Record 33 of Set 11 | suntar
# Processing Record 34 of Set 11 | kurchum
# Processing Record 35 of Set 11 | kamaishi
# Processing Record 36 of Set 11 | dubai
# Processing Record 37 of Set 11 | pacific grove
# Processing Record 38 of Set 11 | kununurra
# Processing Record 39 of Set 11 | iwanai
# Processing Record 40 of Set 11 | ambovombe
# Processing Record 41 of Set 11 | kalmunai
# Processing Record 42 of Set 11 | ahipara
# Processing Record 43 of Set 11 | vanimo
# Processing Record 44 of Set 11 | maiduguri
# Processing Record 45 of Set 11 | bathsheba
# Processing Record 46 of Set 11 | navalmoral de la mata
# Processing Record 47 of Set 11 | kapit
# Processing Record 48 of Set 11 | snyder
# Processing Record 49 of Set 11 | curup
# Processing Record 50 of Set 11 | sawakin
# Processing Record 1 of Set 12 | bongandanga
# Processing Record 2 of Set 12 | bozova
# Processing Record 3 of Set 12 | sorland
# Processing Record 4 of Set 12 | honiara
# Processing Record 5 of Set 12 | faya
# Processing Record 6 of Set 12 | montes altos
# Processing Record 7 of Set 12 | handwara
# City not found. Skipping...
# Processing Record 8 of Set 12 | saint-joseph
# Processing Record 9 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 12 | kavaratti
# Processing Record 11 of Set 12 | adrar
# Processing Record 12 of Set 12 | manta
# Processing Record 13 of Set 12 | petatlan
# Processing Record 14 of Set 12 | kushiro
# Processing Record 15 of Set 12 | palmer
# Processing Record 16 of Set 12 | stromness
# Processing Record 17 of Set 12 | tessalit
# Processing Record 18 of Set 12 | olafsvik
# Processing Record 19 of Set 12 | jian
# Processing Record 20 of Set 12 | amuntai
# Processing Record 21 of Set 12 | ucluelet
# Processing Record 22 of Set 12 | nandu
# Processing Record 23 of Set 12 | watertown
# Processing Record 24 of Set 12 | cody
# Processing Record 25 of Set 12 | san buenaventura
# Processing Record 26 of Set 12 | sungaipenuh
# Processing Record 27 of Set 12 | evensk
# Processing Record 28 of Set 12 | paamiut
# Processing Record 29 of Set 12 | othonoi
# City not found. Skipping...
# Processing Record 30 of Set 12 | wajima
# Processing Record 31 of Set 12 | dothan
# Processing Record 32 of Set 12 | garowe
# Processing Record 33 of Set 12 | kalmar
# Processing Record 34 of Set 12 | buckeye
# Processing Record 35 of Set 12 | lagoa
# Processing Record 36 of Set 12 | suclayin
# Processing Record 37 of Set 12 | ligayan
# Processing Record 38 of Set 12 | bolobo
# Processing Record 39 of Set 12 | datong
# Processing Record 40 of Set 12 | tiarei
# Processing Record 41 of Set 12 | urdoma
# Processing Record 42 of Set 12 | allapalli
# Processing Record 43 of Set 12 | heyang
# Processing Record 44 of Set 12 | laguna
# Processing Record 45 of Set 12 | hakui
# Processing Record 46 of Set 12 | cascais
# Processing Record 47 of Set 12 | north bend
# Processing Record 48 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 12 | hovd
# Processing Record 50 of Set 12 | cotija
# City not found. Skipping...
# Processing Record 1 of Set 13 | polyarnyy
# Processing Record 2 of Set 13 | quang ngai
# Processing Record 3 of Set 13 | jizan
# Processing Record 4 of Set 13 | fare
# Processing Record 5 of Set 13 | carutapera
# Processing Record 6 of Set 13 | graham
# Processing Record 7 of Set 13 | samoylovka
# Processing Record 8 of Set 13 | las vegas
# Processing Record 9 of Set 13 | tezu
# Processing Record 10 of Set 13 | alushta
# Processing Record 11 of Set 13 | egersund
# Processing Record 12 of Set 13 | dalmatovo
# Processing Record 13 of Set 13 | sudbury
# Processing Record 14 of Set 13 | madras
# Processing Record 15 of Set 13 | nova olimpia
# Processing Record 16 of Set 13 | alterosa
# Processing Record 17 of Set 13 | yaan
# Processing Record 18 of Set 13 | aswan
# Processing Record 19 of Set 13 | japeri
# Processing Record 20 of Set 13 | ewa beach
# Processing Record 21 of Set 13 | portland
# Processing Record 22 of Set 13 | inta
# Processing Record 23 of Set 13 | vila
# Processing Record 24 of Set 13 | sterlibashevo
# Processing Record 25 of Set 13 | graaff-reinet
# Processing Record 26 of Set 13 | pontianak
# Processing Record 27 of Set 13 | baghdad
# Processing Record 28 of Set 13 | northam
# Processing Record 29 of Set 13 | tres barras
# Processing Record 30 of Set 13 | pandharpur
# Processing Record 31 of Set 13 | kaka
# Processing Record 32 of Set 13 | tucupita
# Processing Record 33 of Set 13 | zhangye
# Processing Record 34 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 13 | carballo
# Processing Record 36 of Set 13 | nhulunbuy
# Processing Record 37 of Set 13 | shache
# Processing Record 38 of Set 13 | sokolo
# Processing Record 39 of Set 13 | camargo
# Processing Record 40 of Set 13 | nuevitas
# Processing Record 41 of Set 13 | concordia
# Processing Record 42 of Set 13 | kismayo
# Processing Record 43 of Set 13 | kieta
# Processing Record 44 of Set 13 | sanctorum
# Processing Record 45 of Set 13 | medicine hat
# Processing Record 46 of Set 13 | marondera
# Processing Record 47 of Set 13 | ostrovnoy
# Processing Record 48 of Set 13 | stafford
# Processing Record 49 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 13 | bocaiuva
# Processing Record 1 of Set 14 | pleasant point
# Processing Record 2 of Set 14 | kilindoni
# Processing Record 3 of Set 14 | umba
# Processing Record 4 of Set 14 | khorramshahr
# Processing Record 5 of Set 14 | balteni
# Processing Record 6 of Set 14 | tacuarembo
# Processing Record 7 of Set 14 | diamantino
# Processing Record 8 of Set 14 | chara
# Processing Record 9 of Set 14 | vaitape
# Processing Record 10 of Set 14 | newport
# Processing Record 11 of Set 14 | karratha
# Processing Record 12 of Set 14 | kudahuvadhoo
# Processing Record 13 of Set 14 | akersberga
# Processing Record 14 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 15 of Set 14 | goderich
# Processing Record 16 of Set 14 | barcelona
# Processing Record 17 of Set 14 | krutinka
# Processing Record 18 of Set 14 | mackay
# Processing Record 19 of Set 14 | sulangan
# Processing Record 20 of Set 14 | nicoya
# Processing Record 21 of Set 14 | myitkyina
# Processing Record 22 of Set 14 | lenine
# Processing Record 23 of Set 14 | dingle
# Processing Record 24 of Set 14 | palu
# Processing Record 25 of Set 14 | kroya
# Processing Record 26 of Set 14 | marfino
# Processing Record 27 of Set 14 | nizhniy kuranakh
# Processing Record 28 of Set 14 | pangnirtung
# Processing Record 29 of Set 14 | sirsi
# Processing Record 30 of Set 14 | san francisco
# Processing Record 31 of Set 14 | kargopol
# Processing Record 32 of Set 14 | bagdarin
# Processing Record 33 of Set 14 | pangkalanbuun
# Processing Record 34 of Set 14 | bend
# Processing Record 35 of Set 14 | lima
# Processing Record 36 of Set 14 | santa ana
# Processing Record 37 of Set 14 | hirara
# Processing Record 38 of Set 14 | beyla
# Processing Record 39 of Set 14 | kerema
# Processing Record 40 of Set 14 | cayenne
# Processing Record 41 of Set 14 | atambua
# Processing Record 42 of Set 14 | balkanabat
# Processing Record 43 of Set 14 | san fernando
# Processing Record 44 of Set 14 | pavlodar
# Processing Record 45 of Set 14 | doliana
# Processing Record 46 of Set 14 | nantucket
# Processing Record 47 of Set 14 | havoysund
# Processing Record 48 of Set 14 | caernarfon
# Processing Record 49 of Set 14 | lahij
# Processing Record 50 of Set 14 | biak
# Processing Record 1 of Set 15 | dong hoi
# Processing Record 2 of Set 15 | kindu
# Processing Record 3 of Set 15 | kavali
# Processing Record 4 of Set 15 | yumen
# Processing Record 5 of Set 15 | koryukivka
# Processing Record 6 of Set 15 | abbeville
# Processing Record 7 of Set 15 | ahuimanu
# Processing Record 8 of Set 15 | whyalla
# Processing Record 9 of Set 15 | pauini
# Processing Record 10 of Set 15 | eydhafushi
# Processing Record 11 of Set 15 | khash
# Processing Record 12 of Set 15 | deputatskiy
# Processing Record 13 of Set 15 | santa fe
# Processing Record 14 of Set 15 | mayumba
# Processing Record 15 of Set 15 | oktyabrskoye
# Processing Record 16 of Set 15 | maldonado
# Processing Record 17 of Set 15 | odoreu
# Processing Record 18 of Set 15 | port hedland
# Processing Record 19 of Set 15 | gewane
# Processing Record 20 of Set 15 | selenginsk
# Processing Record 21 of Set 15 | mersing
# Processing Record 22 of Set 15 | puerto leguizamo
# Processing Record 23 of Set 15 | berezovyy
# Processing Record 24 of Set 15 | wahpeton
# Processing Record 25 of Set 15 | pochutla
# Processing Record 26 of Set 15 | taos
# Processing Record 27 of Set 15 | muroto
# Processing Record 28 of Set 15 | inndyr
# Processing Record 29 of Set 15 | cururupu
# Processing Record 30 of Set 15 | khandyga
# Processing Record 31 of Set 15 | meulaboh
# Processing Record 32 of Set 15 | kita
# Processing Record 33 of Set 15 | san luis obispo
# Processing Record 34 of Set 15 | lasa
# Processing Record 35 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 15 | kasongo-lunda
# Processing Record 37 of Set 15 | chumikan
# Processing Record 38 of Set 15 | elliot
# Processing Record 39 of Set 15 | xinyu
# Processing Record 40 of Set 15 | pendencias
# Processing Record 41 of Set 15 | burnie
# Processing Record 42 of Set 15 | lunen
# Processing Record 43 of Set 15 | kastamonu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Namatanai      PG  -3.6667  152.4333     85.05        69          82
# 1       Tuy Hoa      VN  13.0833  109.3000     79.77        70          43
# 2        Bonthe      SL   7.5264  -12.5050     78.66        83          99
# 3         Tiksi      RU  71.6872  128.8694      7.56        85         100
# 4     Upernavik      GL  72.7868  -56.1549      4.17        88         100
# 5        Atuona      PF  -9.8000 -139.0333     80.73        73          64
# 6         Vaini      TO -21.2000 -175.2000     80.60        69          20
# 7         Aldan      RU  58.6031  125.3894     24.75        72         100
# 8  Punta Arenas      CL -53.1500  -70.9167     53.60        54          75
# 9    Butaritari      KI   3.0707  172.7902     82.29        77          98
#
#    Wind Speed Weather Description
# 0       13.80       broken clouds
# 1        4.27    scattered clouds
# 2        2.17     overcast clouds
# 3        9.46     overcast clouds
# 4        8.12     overcast clouds
# 5       19.73       broken clouds
# 6        5.75          few clouds
# 7        5.01     overcast clouds
# 8        9.22       broken clouds
# 9        9.04          light rain

# %%
# Create the output file (CSV).
output_data_file = "./WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
